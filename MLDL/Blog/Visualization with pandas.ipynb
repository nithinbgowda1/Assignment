# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn,randint,uniform,sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07',periods=1000),columns=['values'])
df.head()
# Out:
#               values
# 2019-06-07  0.844688
# 2019-06-08 -0.982638
# 2019-06-09  1.902591
# 2019-06-10 -0.937312
# 2019-06-11 -0.875503

# %%
df.tail()
# Out:
#               values
# 2022-02-26 -1.295192
# 2022-02-27 -1.383148
# 2022-02-28 -0.700616
# 2022-03-01  0.516274
# 2022-03-02  0.889274

# %%
ts = pd.Series(randn(1000),index = pd.date_range('2019-06-07', periods = 1000))
ts
# Out:
# 2019-06-07   -1.148818
# 2019-06-08    1.401898
# 2019-06-09   -1.636495
# 2019-06-10   -0.542075
# 2019-06-11    0.119095
#                 ...
# 2022-02-26   -0.646097
# 2022-02-27   -0.257274
# 2022-02-28   -1.078604
# 2022-03-01   -2.051567
# 2022-03-02   -2.083265
# Freq: D, Length: 1000, dtype: float64

# %%
ts.head()
# Out:
# 2019-06-07   -1.031940
# 2019-06-08    0.612108
# 2019-06-09   -0.398743
# 2019-06-10    0.291535
# 2019-06-11   -0.419832
# Freq: D, dtype: float64

# %%
ts.tail()
# Out:
# 2022-02-26   -0.646097
# 2022-02-27   -0.257274
# 2022-02-28   -1.078604
# 2022-03-01   -2.051567
# 2022-03-02   -2.083265
# Freq: D, dtype: float64

# %%
df['values'] = df['values'].cumsum()

# %%
df
# Out:
#                values
# 2019-06-07   0.844688
# 2019-06-08  -0.137950
# 2019-06-09   1.764641
# 2019-06-10   0.827329
# 2019-06-11  -0.048174
# ...               ...
# 2022-02-26 -19.904694
# 2022-02-27 -21.287841
# 2022-02-28 -21.988458
# 2022-03-01 -21.472184
# 2022-03-02 -20.582910
#
# [1000 rows x 1 columns]

# %%
df.head()
# Out:
#               values
# 2019-06-07  0.844688
# 2019-06-08 -0.137950
# 2019-06-09  1.764641
# 2019-06-10  0.827329
# 2019-06-11 -0.048174

# %%
ts = ts.cumsum()
ts
# Out:
# 2019-06-07    -1.148818
# 2019-06-08     0.253080
# 2019-06-09    -1.383416
# 2019-06-10    -1.925491
# 2019-06-11    -1.806396
#                 ...
# 2022-02-26   -43.269692
# 2022-02-27   -43.526966
# 2022-02-28   -44.605570
# 2022-03-01   -46.657137
# 2022-03-02   -48.740402
# Freq: D, Length: 1000, dtype: float64

# %%
ts.head()
# Out:
# 2019-06-07   -1.148818
# 2019-06-08    0.253080
# 2019-06-09   -1.383416
# 2019-06-10   -1.925491
# 2019-06-11   -1.806396
# Freq: D, dtype: float64

# %%
ts.tail()
# Out:
# 2022-02-26   -43.269692
# 2022-02-27   -43.526966
# 2022-02-28   -44.605570
# 2022-03-01   -46.657137
# 2022-03-02   -48.740402
# Freq: D, dtype: float64

# %%
type(df),type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize = (5,5))

# %%
plt.plot(ts)

# %%
df.plot()

# %%
plt.plot(df)

# %%
iris = sb.load_dataset('iris')
len(iris)
# Out:
# 150

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plot_iris = iris.plot(figsize=(15,8))
plot_iris.set_xlabel('X-Axis')
plot_iris.set_ylabel('Y-axis')
plot_iris.set_title('Iris Data set')
# Out:
# Text(0.5, 1.0, 'Iris Data set')

# %%
ts.plot(kind='hist')

# %%
df1 = iris.drop(['species'],axis=1)
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df1.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df1.iloc[0].plot(kind='bar')

# %%
titanic =sb.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind='bar')

# %%
data = pd.DataFrame(randn(10,4),columns=['a','b','c','d'])

# %%
data
# Out:
#           a         b         c         d
# 0 -1.255350  0.736286  0.985502  2.464429
# 1 -2.069137 -2.677648 -1.019646 -0.004964
# 2  0.006552 -0.274645 -0.968035 -0.011405
# 3 -0.744620  1.231328  0.914955  0.063153
# 4  2.148772 -0.202673  0.483592 -2.009638
# 5  0.600630 -1.122183  0.311004  1.357574
# 6  0.492735  1.062266 -2.141917 -0.762291
# 7 -1.047552  0.935051 -0.207406  0.439969
# 8 -0.689928 -1.135773 -1.449642  1.058887
# 9 -0.236174 -0.275188  0.686132  0.283400

# %%
data.head()
# Out:
#           a         b         c         d
# 0 -1.255350  0.736286  0.985502  2.464429
# 1 -2.069137 -2.677648 -1.019646 -0.004964
# 2  0.006552 -0.274645 -0.968035 -0.011405
# 3 -0.744620  1.231328  0.914955  0.063153
# 4  2.148772 -0.202673  0.483592 -2.009638

# %%
img = np.random.randn(768,1024)

# %%
plt.imshow(img)

# %%
data.plot.bar()

# %%
data.plot.barh()

# %%
iris.plot.hist()

# %%
iris['sepal_width'].diff().histst(color='b',alpha=0.1)
